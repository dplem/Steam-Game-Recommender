# %%
import pandas as pd

# %%
steam_meta_data = pd.read_csv(r"C:\Users\Derek\Desktop\steam-games\steam_games_working.csv")

# %%
steam_meta_data
# Out:
#                                                      url types  \
# 0        https://store.steampowered.com/app/379720/DOOM/   app
# 1      https://store.steampowered.com/app/578080/PLAY...   app
# 2      https://store.steampowered.com/app/637090/BATT...   app
# 3        https://store.steampowered.com/app/221100/DayZ/   app
# 4      https://store.steampowered.com/app/8500/EVE_On...   app
# ...                                                  ...   ...
# 40829  https://store.steampowered.com/app/899836/Rock...   app
# 40830  https://store.steampowered.com/app/899832/Rock...   app
# 40831  https://store.steampowered.com/app/906840/Fant...   app
# 40832  https://store.steampowered.com/app/906635/Mega...   app
# 40833  https://store.steampowered.com/app/908000/Stor...   app
#
#                                                     Game  \
# 0                                                   DOOM
# 1                          PLAYERUNKNOWN'S BATTLEGROUNDS
# ...

# %%
steam_meta_data = steam_meta_data.drop_duplicates()
steam_meta_data
# Out:
#                                                      url types  \
# 0        https://store.steampowered.com/app/379720/DOOM/   app
# 1      https://store.steampowered.com/app/578080/PLAY...   app
# 2      https://store.steampowered.com/app/637090/BATT...   app
# 3        https://store.steampowered.com/app/221100/DayZ/   app
# 4      https://store.steampowered.com/app/8500/EVE_On...   app
# ...                                                  ...   ...
# 40829  https://store.steampowered.com/app/899836/Rock...   app
# 40830  https://store.steampowered.com/app/899832/Rock...   app
# 40831  https://store.steampowered.com/app/906840/Fant...   app
# 40832  https://store.steampowered.com/app/906635/Mega...   app
# 40833  https://store.steampowered.com/app/908000/Stor...   app
#
#                                                     Game  \
# 0                                                   DOOM
# 1                          PLAYERUNKNOWN'S BATTLEGROUNDS
# ...

# %%
steam_user_data = pd.read_csv(r"C:\Users\Derek\Desktop\steam-games\steam-200k_v2.csv")
steam_user_data
# Out:
#           user_id                        Game purchase_play  Hours  something
# 0       151603712  The Elder Scrolls V Skyrim      purchase    1.0          0
# 1       151603712  The Elder Scrolls V Skyrim          play  273.0          0
# 2       151603712                   Fallout 4      purchase    1.0          0
# 3       151603712                   Fallout 4          play   87.0          0
# 4       151603712                       Spore      purchase    1.0          0
# ...           ...                         ...           ...    ...        ...
# 199995  128470551                 Titan Souls          play    1.5          0
# 199996  128470551  Grand Theft Auto Vice City      purchase    1.0          0
# 199997  128470551  Grand Theft Auto Vice City          play    1.5          0
# 199998  128470551                        RUSH      purchase    1.0          0
# 199999  128470551                        RUSH          play    1.4          0
#
# [200000 rows x 5 columns]

# %%
steam_user_data = steam_user_data.drop_duplicates()
steam_user_data
# Out:
#           user_id                        Game purchase_play  Hours  something
# 0       151603712  The Elder Scrolls V Skyrim      purchase    1.0          0
# 1       151603712  The Elder Scrolls V Skyrim          play  273.0          0
# 2       151603712                   Fallout 4      purchase    1.0          0
# 3       151603712                   Fallout 4          play   87.0          0
# 4       151603712                       Spore      purchase    1.0          0
# ...           ...                         ...           ...    ...        ...
# 199995  128470551                 Titan Souls          play    1.5          0
# 199996  128470551  Grand Theft Auto Vice City      purchase    1.0          0
# 199997  128470551  Grand Theft Auto Vice City          play    1.5          0
# 199998  128470551                        RUSH      purchase    1.0          0
# 199999  128470551                        RUSH          play    1.4          0
#
# [198283 rows x 5 columns]

# %%
steam_reviews = pd.read_csv(r"C:\Users\Derek\Desktop\steam-games\steam_reviews.csv")
steam_reviews
# Out:
#        date_posted  funny  helpful  hour_played  is_early_access_review  \
# 0       2019-02-10      2        4          578                   False
# 1       2019-02-10      0        0          184                   False
# 2       2019-02-07      0        0          892                   False
# 3       2018-06-14    126     1086          676                   False
# 4       2017-06-20     85     2139          612                   False
# ...            ...    ...      ...          ...                     ...
# 434886  2018-11-17      1       37           10                   False
# 434887  2018-11-17      3       41           38                   False
# 434888  2018-11-20      0        0           36                   False
# 434889  2018-11-18      1       44           12                   False
# 434890  2019-01-21      1       28           20                   False
#
#        recommendation                                             review  \
# ...

# %%
steam_reviews = steam_reviews.drop_duplicates()
steam_reviews
# Out:
#        date_posted  funny  helpful  hour_played  is_early_access_review  \
# 0       2019-02-10      2        4          578                   False
# 1       2019-02-10      0        0          184                   False
# 2       2019-02-07      0        0          892                   False
# 3       2018-06-14    126     1086          676                   False
# 4       2017-06-20     85     2139          612                   False
# ...            ...    ...      ...          ...                     ...
# 434886  2018-11-17      1       37           10                   False
# 434887  2018-11-17      3       41           38                   False
# 434888  2018-11-20      0        0           36                   False
# 434889  2018-11-18      1       44           12                   False
# 434890  2019-01-21      1       28           20                   False
#
#        recommendation                                             review  \
# ...

# %%
df = pd.merge(steam_user_data, steam_meta_data, on='Game')

# %%
df
# Out:
#           user_id                        Game purchase_play  Hours  something  \
# 0       151603712  The Elder Scrolls V Skyrim      purchase    1.0          0
# 1       151603712  The Elder Scrolls V Skyrim          play  273.0          0
# 2        59945701  The Elder Scrolls V Skyrim      purchase    1.0          0
# 3        59945701  The Elder Scrolls V Skyrim          play   58.0          0
# 4        53875128  The Elder Scrolls V Skyrim      purchase    1.0          0
# ...           ...                         ...           ...    ...        ...
# 140535  116564064          Warriors & Castles      purchase    1.0          0
# 140536  135400225                Life is Hard      purchase    1.0          0
# 140537  135400225                Life is Hard          play    3.1          0
# 140538  135400225           Executive Assault      purchase    1.0          0
# 140539  135400225           Executive Assault          play    2.7          0
#
# ...

# %%
# saving the DataFrame as a CSV file 
save_csv = df.to_csv('Steam_merged_dataset.csv', index = False)

# %%
save_csv
